# %%
import numpy as np
import tensorflow as tf
x = np.array([[1,2,3],[4,5,6]])
y = np.array([[2,4,6],[8,10,12]])
z = np.array([i+j for i,j in zip(x,y) ])
sentence = ["Kunle", "is", "a", "bastard"]
[word.split() for word in sentence]
#z = [1]*10
#list(z)

# %%
# %run train.py

# %%
# %run test.py
